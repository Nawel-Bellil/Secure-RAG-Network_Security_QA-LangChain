# %%
import os
from typing import List, Optional
from langchain.agents import create_agent

# %%
os.environ['GROQ_API_KEY'] = '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'

# %%
agent = create_agent(
    model='groq:llama-3.1-8b-instant',
    tools = [],
    system_prompt="you are a helpful chat assistant. Be clear, concise, and polite. Understand the user's intent and respond directly. Stay professional and safe.",

)

result = agent.invoke(
    {
        "messaes":[{"role":"user", "content":" Explain Machine Learning in simple terms."}],
    }
)

# %%
print(result)
# Out:
# {'messages': [AIMessage(content='How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 59, 'total_tokens': 67, 'completion_time': 0.006210062, 'completion_tokens_details': None, 'prompt_time': 0.00404035, 'prompt_tokens_details': None, 'queue_time': 0.089392732, 'total_time': 0.010250412}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--cbafbca3-f755-42c0-b16b-0efb4900da49-0', usage_metadata={'input_tokens': 59, 'output_tokens': 8, 'total_tokens': 67})]}

# %%
print(result["messages"])
# Out:
# [AIMessage(content='How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 59, 'total_tokens': 67, 'completion_time': 0.006210062, 'completion_tokens_details': None, 'prompt_time': 0.00404035, 'prompt_tokens_details': None, 'queue_time': 0.089392732, 'total_time': 0.010250412}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--cbafbca3-f755-42c0-b16b-0efb4900da49-0', usage_metadata={'input_tokens': 59, 'output_tokens': 8, 'total_tokens': 67})]

# %%
chat_history = []

while True:
    user_input = input("User: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting chat.")
        break
    chat_history.append(f"user: {user_input}")

messages = chat_history + [{"role": "user", "content": user_input}]
result = agent.invoke(
    {
        "messages": messages,
    }
)

try:
    reply = result["messages"][-1].content
except Exception as e:
    reply = str(e)
    
print(f"Assistant: {reply}")

chat_history.append({"role": "user", "content": user_input})
chat_history.append({"role": "assistant", "content": reply})
